# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Get the nearest city using the citipy module
from citipy import citipy

coordinates = list(lat_lngs)

# %%
# Create a list for cities.
cities = []
# Identify latitude and longitude combination the nearest cities.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

# If city is not present ad to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count 
len(cities)
# Out:
# 757

# %%
# Import the requests.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create counters.
record_count = 1
set_count = 1

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

# Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
# Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

# Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
# Add 1 to the record count.
    record_count += 1       
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                              "Country": city_country,
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Current Description": city_weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | kenai
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | amqui
# Processing Record 5 of Set 1 | bambous virieux
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | lagoa
# Processing Record 8 of Set 1 | batagay
# Processing Record 9 of Set 1 | mar del plata
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | buraydah
# Processing Record 12 of Set 1 | huarmey
# Processing Record 13 of Set 1 | nantucket
# Processing Record 14 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | smithers
# Processing Record 18 of Set 1 | valvedditturai
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | conceicao do araguaia
# Processing Record 22 of Set 1 | klaksvik
# Processing Record 23 of Set 1 | zhigansk
# Processing Record 24 of Set 1 | barrow
# Processing Record 25 of Set 1 | sur
# Processing Record 26 of Set 1 | tuatapere
# Processing Record 27 of Set 1 | hasaki
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | pevek
# Processing Record 30 of Set 1 | aginskoye
# Processing Record 31 of Set 1 | lavrentiya
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | tezu
# Processing Record 34 of Set 1 | cherskiy
# Processing Record 35 of Set 1 | saldanha
# Processing Record 36 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 1 | kodiak
# Processing Record 38 of Set 1 | tubarao
# Processing Record 39 of Set 1 | vaini
# Processing Record 40 of Set 1 | praia da vitoria
# Processing Record 41 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | bengkulu
# Processing Record 45 of Set 1 | thompson
# Processing Record 46 of Set 1 | rabaul
# Processing Record 47 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 48 of Set 1 | consett
# Processing Record 49 of Set 1 | roma
# Processing Record 50 of Set 1 | te anau
# Processing Record 1 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 2 | port alfred
# Processing Record 3 of Set 2 | rawah
# Processing Record 4 of Set 2 | codrington
# Processing Record 5 of Set 2 | jijiga
# Processing Record 6 of Set 2 | kapaa
# Processing Record 7 of Set 2 | tuktoyaktuk
# Processing Record 8 of Set 2 | new ross
# Processing Record 9 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 2 | carutapera
# Processing Record 11 of Set 2 | castro
# Processing Record 12 of Set 2 | kautokeino
# Processing Record 13 of Set 2 | maniitsoq
# Processing Record 14 of Set 2 | nikolskoye
# Processing Record 15 of Set 2 | kuldur
# Processing Record 16 of Set 2 | tilichiki
# Processing Record 17 of Set 2 | cape town
# Processing Record 18 of Set 2 | grindavik
# Processing Record 19 of Set 2 | portland
# Processing Record 20 of Set 2 | voh
# Processing Record 21 of Set 2 | arraial do cabo
# Processing Record 22 of Set 2 | sinaloa
# Processing Record 23 of Set 2 | taoudenni
# Processing Record 24 of Set 2 | aklavik
# Processing Record 25 of Set 2 | upernavik
# Processing Record 26 of Set 2 | mahebourg
# Processing Record 27 of Set 2 | homer
# Processing Record 28 of Set 2 | hobart
# Processing Record 29 of Set 2 | flinders
# Processing Record 30 of Set 2 | bubaque
# Processing Record 31 of Set 2 | san antonio
# Processing Record 32 of Set 2 | seymchan
# Processing Record 33 of Set 2 | college
# Processing Record 34 of Set 2 | empangeni
# Processing Record 35 of Set 2 | san pedro de macoris
# Processing Record 36 of Set 2 | igrim
# Processing Record 37 of Set 2 | taltal
# Processing Record 38 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 41 of Set 2 | pangnirtung
# Processing Record 42 of Set 2 | taburi
# City not found. Skipping...
# Processing Record 43 of Set 2 | namatanai
# Processing Record 44 of Set 2 | saint anthony
# Processing Record 45 of Set 2 | avarua
# Processing Record 46 of Set 2 | forset
# City not found. Skipping...
# Processing Record 47 of Set 2 | port elizabeth
# Processing Record 48 of Set 2 | charters towers
# Processing Record 49 of Set 2 | bathsheba
# Processing Record 50 of Set 2 | ust-tsilma
# Processing Record 1 of Set 3 | new norfolk
# Processing Record 2 of Set 3 | saint-philippe
# Processing Record 3 of Set 3 | provideniya
# Processing Record 4 of Set 3 | fare
# Processing Record 5 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 3 | monster
# Processing Record 7 of Set 3 | macklin
# Processing Record 8 of Set 3 | cabedelo
# Processing Record 9 of Set 3 | reconquista
# Processing Record 10 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 3 | aleksandrov gay
# Processing Record 12 of Set 3 | bambanglipuro
# Processing Record 13 of Set 3 | kaitangata
# Processing Record 14 of Set 3 | saskylakh
# Processing Record 15 of Set 3 | constitucion
# Processing Record 16 of Set 3 | alofi
# Processing Record 17 of Set 3 | bonnyville
# Processing Record 18 of Set 3 | victoria
# Processing Record 19 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 3 | yellowknife
# Processing Record 21 of Set 3 | kolaras
# Processing Record 22 of Set 3 | margate
# Processing Record 23 of Set 3 | esmeraldas
# Processing Record 24 of Set 3 | kiama
# Processing Record 25 of Set 3 | bulgan
# Processing Record 26 of Set 3 | albany
# Processing Record 27 of Set 3 | mount gambier
# Processing Record 28 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 3 | airai
# Processing Record 30 of Set 3 | yumen
# Processing Record 31 of Set 3 | torbay
# Processing Record 32 of Set 3 | fuerte olimpo
# Processing Record 33 of Set 3 | ahipara
# Processing Record 34 of Set 3 | sarany
# Processing Record 35 of Set 3 | eldikan
# City not found. Skipping...
# Processing Record 36 of Set 3 | narsaq
# Processing Record 37 of Set 3 | vila velha
# Processing Record 38 of Set 3 | puyo
# Processing Record 39 of Set 3 | ponta do sol
# Processing Record 40 of Set 3 | hilo
# Processing Record 41 of Set 3 | konstantinovka
# Processing Record 42 of Set 3 | havelock
# Processing Record 43 of Set 3 | nanortalik
# Processing Record 44 of Set 3 | icod de los vinos
# Processing Record 45 of Set 3 | muroto
# Processing Record 46 of Set 3 | luderitz
# Processing Record 47 of Set 3 | skelleftea
# Processing Record 48 of Set 3 | chervona sloboda
# Processing Record 49 of Set 3 | yar-sale
# Processing Record 50 of Set 3 | kirakira
# Processing Record 1 of Set 4 | ketchikan
# Processing Record 2 of Set 4 | qaanaaq
# Processing Record 3 of Set 4 | severo-kurilsk
# Processing Record 4 of Set 4 | wattegama
# Processing Record 5 of Set 4 | chicama
# Processing Record 6 of Set 4 | gorontalo
# Processing Record 7 of Set 4 | katsuura
# Processing Record 8 of Set 4 | sitrah
# Processing Record 9 of Set 4 | aykhal
# Processing Record 10 of Set 4 | kruisfontein
# Processing Record 11 of Set 4 | khatanga
# Processing Record 12 of Set 4 | ribeira grande
# Processing Record 13 of Set 4 | kimbe
# Processing Record 14 of Set 4 | cayenne
# Processing Record 15 of Set 4 | bethel
# Processing Record 16 of Set 4 | matara
# Processing Record 17 of Set 4 | acapulco
# Processing Record 18 of Set 4 | ossora
# Processing Record 19 of Set 4 | padang
# Processing Record 20 of Set 4 | rock sound
# Processing Record 21 of Set 4 | asau
# Processing Record 22 of Set 4 | faanui
# Processing Record 23 of Set 4 | winnemucca
# Processing Record 24 of Set 4 | mandalgovi
# Processing Record 25 of Set 4 | tsogni
# Processing Record 26 of Set 4 | raytown
# Processing Record 27 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 4 | aguililla
# Processing Record 29 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 4 | chuy
# Processing Record 31 of Set 4 | georgetown
# Processing Record 32 of Set 4 | nueva gerona
# Processing Record 33 of Set 4 | fagernes
# Processing Record 34 of Set 4 | ostrovnoy
# Processing Record 35 of Set 4 | zharkent
# Processing Record 36 of Set 4 | noumea
# Processing Record 37 of Set 4 | waipawa
# Processing Record 38 of Set 4 | hovd
# Processing Record 39 of Set 4 | moyale
# Processing Record 40 of Set 4 | bad neustadt
# City not found. Skipping...
# Processing Record 41 of Set 4 | broken hill
# Processing Record 42 of Set 4 | matiari
# Processing Record 43 of Set 4 | lebu
# Processing Record 44 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 45 of Set 4 | tasiilaq
# Processing Record 46 of Set 4 | cabo san lucas
# Processing Record 47 of Set 4 | tsienyane
# City not found. Skipping...
# Processing Record 48 of Set 4 | jacareacanga
# Processing Record 49 of Set 4 | vardo
# Processing Record 50 of Set 4 | grand-lahou
# Processing Record 1 of Set 5 | namibe
# Processing Record 2 of Set 5 | alice springs
# Processing Record 3 of Set 5 | kysyl-syr
# Processing Record 4 of Set 5 | havre-saint-pierre
# Processing Record 5 of Set 5 | balkhash
# Processing Record 6 of Set 5 | lasa
# Processing Record 7 of Set 5 | strezhevoy
# Processing Record 8 of Set 5 | souillac
# Processing Record 9 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 5 | wum
# Processing Record 12 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 5 | ballina
# Processing Record 14 of Set 5 | malpe
# Processing Record 15 of Set 5 | zhanaozen
# Processing Record 16 of Set 5 | tiksi
# Processing Record 17 of Set 5 | mocuba
# Processing Record 18 of Set 5 | chokurdakh
# Processing Record 19 of Set 5 | shache
# Processing Record 20 of Set 5 | cap-aux-meules
# Processing Record 21 of Set 5 | muscatine
# Processing Record 22 of Set 5 | storsteinnes
# Processing Record 23 of Set 5 | clyde river
# Processing Record 24 of Set 5 | longyearbyen
# Processing Record 25 of Set 5 | kalemie
# Processing Record 26 of Set 5 | talnakh
# Processing Record 27 of Set 5 | salalah
# Processing Record 28 of Set 5 | soverato
# Processing Record 29 of Set 5 | ternate
# Processing Record 30 of Set 5 | bandarbeyla
# Processing Record 31 of Set 5 | atar
# Processing Record 32 of Set 5 | fairbanks
# Processing Record 33 of Set 5 | ostersund
# Processing Record 34 of Set 5 | auki
# Processing Record 35 of Set 5 | evensk
# Processing Record 36 of Set 5 | parana
# Processing Record 37 of Set 5 | washington
# Processing Record 38 of Set 5 | laibin
# Processing Record 39 of Set 5 | kavieng
# Processing Record 40 of Set 5 | araouane
# Processing Record 41 of Set 5 | port lincoln
# Processing Record 42 of Set 5 | canala
# Processing Record 43 of Set 5 | egvekinot
# Processing Record 44 of Set 5 | honiara
# Processing Record 45 of Set 5 | sandwick
# Processing Record 46 of Set 5 | lata
# Processing Record 47 of Set 5 | puerto baquerizo moreno
# Processing Record 48 of Set 5 | sakakah
# Processing Record 49 of Set 5 | cherepovets
# Processing Record 50 of Set 5 | erzin
# Processing Record 1 of Set 6 | walcz
# Processing Record 2 of Set 6 | urengoy
# Processing Record 3 of Set 6 | barinas
# Processing Record 4 of Set 6 | hobyo
# Processing Record 5 of Set 6 | manono
# Processing Record 6 of Set 6 | mujiayingzi
# Processing Record 7 of Set 6 | vila franca do campo
# Processing Record 8 of Set 6 | chestermere
# Processing Record 9 of Set 6 | dikson
# Processing Record 10 of Set 6 | veraval
# Processing Record 11 of Set 6 | comodoro rivadavia
# Processing Record 12 of Set 6 | anori
# Processing Record 13 of Set 6 | deputatskiy
# Processing Record 14 of Set 6 | camopi
# Processing Record 15 of Set 6 | xixiang
# Processing Record 16 of Set 6 | bustonkala
# City not found. Skipping...
# Processing Record 17 of Set 6 | sobolevo
# Processing Record 18 of Set 6 | semenivka
# Processing Record 19 of Set 6 | kachug
# Processing Record 20 of Set 6 | sorland
# Processing Record 21 of Set 6 | rongcheng
# Processing Record 22 of Set 6 | inuvik
# Processing Record 23 of Set 6 | mercedes
# Processing Record 24 of Set 6 | nakusp
# Processing Record 25 of Set 6 | rey bouba
# Processing Record 26 of Set 6 | abu samrah
# Processing Record 27 of Set 6 | camana
# Processing Record 28 of Set 6 | meadow lake
# Processing Record 29 of Set 6 | khandbari
# Processing Record 30 of Set 6 | gazojak
# Processing Record 31 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 32 of Set 6 | chaumont
# Processing Record 33 of Set 6 | dwarka
# Processing Record 34 of Set 6 | doume
# Processing Record 35 of Set 6 | mayo
# Processing Record 36 of Set 6 | ambon
# Processing Record 37 of Set 6 | pa sang
# Processing Record 38 of Set 6 | urucui
# Processing Record 39 of Set 6 | antigonish
# Processing Record 40 of Set 6 | pasni
# Processing Record 41 of Set 6 | matagami
# Processing Record 42 of Set 6 | zhigalovo
# Processing Record 43 of Set 6 | ayan
# Processing Record 44 of Set 6 | hithadhoo
# Processing Record 45 of Set 6 | muana
# Processing Record 46 of Set 6 | yazman
# Processing Record 47 of Set 6 | sitka
# Processing Record 48 of Set 6 | ilulissat
# Processing Record 49 of Set 6 | paradwip
# City not found. Skipping...
# Processing Record 50 of Set 6 | christchurch
# Processing Record 1 of Set 7 | sabla
# Processing Record 2 of Set 7 | cozumel
# Processing Record 3 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 7 | abu dhabi
# Processing Record 5 of Set 7 | okmulgee
# Processing Record 6 of Set 7 | ulyanovsk
# Processing Record 7 of Set 7 | dali
# Processing Record 8 of Set 7 | marzuq
# Processing Record 9 of Set 7 | terney
# Processing Record 10 of Set 7 | tyukhtet
# Processing Record 11 of Set 7 | kutum
# Processing Record 12 of Set 7 | sapele
# Processing Record 13 of Set 7 | poronaysk
# Processing Record 14 of Set 7 | kalianget
# Processing Record 15 of Set 7 | leningradskiy
# Processing Record 16 of Set 7 | imisli
# City not found. Skipping...
# Processing Record 17 of Set 7 | tabou
# Processing Record 18 of Set 7 | bredasdorp
# Processing Record 19 of Set 7 | sept-iles
# Processing Record 20 of Set 7 | svetlaya
# Processing Record 21 of Set 7 | nuevo progreso
# Processing Record 22 of Set 7 | constantine
# Processing Record 23 of Set 7 | siutu
# City not found. Skipping...
# Processing Record 24 of Set 7 | ancud
# Processing Record 25 of Set 7 | ilhabela
# Processing Record 26 of Set 7 | dolores
# Processing Record 27 of Set 7 | clifton
# Processing Record 28 of Set 7 | daru
# Processing Record 29 of Set 7 | iskateley
# Processing Record 30 of Set 7 | venice
# Processing Record 31 of Set 7 | vilcun
# Processing Record 32 of Set 7 | tolaga bay
# Processing Record 33 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 7 | ende
# Processing Record 35 of Set 7 | mahibadhoo
# Processing Record 36 of Set 7 | shakawe
# Processing Record 37 of Set 7 | saint george
# Processing Record 38 of Set 7 | pimenta bueno
# Processing Record 39 of Set 7 | rome
# Processing Record 40 of Set 7 | porto santo
# Processing Record 41 of Set 7 | rockland
# Processing Record 42 of Set 7 | necochea
# Processing Record 43 of Set 7 | macheng
# Processing Record 44 of Set 7 | cururupu
# Processing Record 45 of Set 7 | lagunas
# Processing Record 46 of Set 7 | lorengau
# Processing Record 47 of Set 7 | carnarvon
# Processing Record 48 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 49 of Set 7 | mehamn
# Processing Record 50 of Set 7 | fortuna
# Processing Record 1 of Set 8 | iquique
# Processing Record 2 of Set 8 | tsaratanana
# Processing Record 3 of Set 8 | atasu
# Processing Record 4 of Set 8 | mikhaylovka
# Processing Record 5 of Set 8 | norman wells
# Processing Record 6 of Set 8 | valparaiso
# Processing Record 7 of Set 8 | johnstown
# Processing Record 8 of Set 8 | yulara
# Processing Record 9 of Set 8 | chipinge
# Processing Record 10 of Set 8 | roebourne
# Processing Record 11 of Set 8 | ilmajoki
# Processing Record 12 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 13 of Set 8 | shaowu
# Processing Record 14 of Set 8 | miri
# Processing Record 15 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 8 | exeter
# Processing Record 17 of Set 8 | broome
# Processing Record 18 of Set 8 | husavik
# Processing Record 19 of Set 8 | barranca
# Processing Record 20 of Set 8 | rawson
# Processing Record 21 of Set 8 | san quintin
# Processing Record 22 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 23 of Set 8 | nouadhibou
# Processing Record 24 of Set 8 | chenzhou
# Processing Record 25 of Set 8 | suntar
# Processing Record 26 of Set 8 | najran
# Processing Record 27 of Set 8 | tommot
# Processing Record 28 of Set 8 | bardiyah
# Processing Record 29 of Set 8 | saint-pierre
# Processing Record 30 of Set 8 | raudeberg
# Processing Record 31 of Set 8 | port blair
# Processing Record 32 of Set 8 | bennington
# Processing Record 33 of Set 8 | yicheng
# Processing Record 34 of Set 8 | piacabucu
# Processing Record 35 of Set 8 | alta floresta
# Processing Record 36 of Set 8 | alugan
# Processing Record 37 of Set 8 | sabang
# Processing Record 38 of Set 8 | east london
# Processing Record 39 of Set 8 | tema
# Processing Record 40 of Set 8 | acari
# Processing Record 41 of Set 8 | hamilton
# Processing Record 42 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 43 of Set 8 | rio grande
# Processing Record 44 of Set 8 | naryan-mar
# Processing Record 45 of Set 8 | khorixas
# Processing Record 46 of Set 8 | dubbo
# Processing Record 47 of Set 8 | chilia veche
# Processing Record 48 of Set 8 | esperance
# Processing Record 49 of Set 8 | asahikawa
# Processing Record 50 of Set 8 | rio gallegos
# Processing Record 1 of Set 9 | phibun mangsahan
# Processing Record 2 of Set 9 | tarija
# Processing Record 3 of Set 9 | babanusah
# City not found. Skipping...
# Processing Record 4 of Set 9 | beira
# Processing Record 5 of Set 9 | magadan
# Processing Record 6 of Set 9 | farafangana
# Processing Record 7 of Set 9 | sechura
# Processing Record 8 of Set 9 | hami
# Processing Record 9 of Set 9 | elmira
# Processing Record 10 of Set 9 | brae
# Processing Record 11 of Set 9 | geresk
# City not found. Skipping...
# Processing Record 12 of Set 9 | riyadh
# Processing Record 13 of Set 9 | adre
# Processing Record 14 of Set 9 | marrakesh
# Processing Record 15 of Set 9 | coahuayana
# Processing Record 16 of Set 9 | lianran
# Processing Record 17 of Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 18 of Set 9 | zumarraga
# Processing Record 19 of Set 9 | tahe
# Processing Record 20 of Set 9 | grove city
# Processing Record 21 of Set 9 | sandnessjoen
# Processing Record 22 of Set 9 | pembroke
# Processing Record 23 of Set 9 | san patricio
# Processing Record 24 of Set 9 | linhares
# Processing Record 25 of Set 9 | poya
# Processing Record 26 of Set 9 | potchefstroom
# Processing Record 27 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 9 | griffith
# Processing Record 30 of Set 9 | sovetskiy
# Processing Record 31 of Set 9 | goderich
# Processing Record 32 of Set 9 | shubarkuduk
# Processing Record 33 of Set 9 | wagar
# Processing Record 34 of Set 9 | lyngseidet
# Processing Record 35 of Set 9 | arman
# Processing Record 36 of Set 9 | svetlyy
# Processing Record 37 of Set 9 | concepcion del uruguay
# Processing Record 38 of Set 9 | merauke
# Processing Record 39 of Set 9 | hebi
# Processing Record 40 of Set 9 | bilma
# Processing Record 41 of Set 9 | juli
# Processing Record 42 of Set 9 | ingham
# Processing Record 43 of Set 9 | ouallam
# Processing Record 44 of Set 9 | tocantinopolis
# City not found. Skipping...
# Processing Record 45 of Set 9 | nouakchott
# Processing Record 46 of Set 9 | black river
# Processing Record 47 of Set 9 | maldonado
# Processing Record 48 of Set 9 | port hardy
# Processing Record 49 of Set 9 | korla
# Processing Record 50 of Set 9 | soe
# Processing Record 1 of Set 10 | naron
# Processing Record 2 of Set 10 | keetmanshoop
# Processing Record 3 of Set 10 | lincoln
# Processing Record 4 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 5 of Set 10 | lazurne
# Processing Record 6 of Set 10 | bandar-e lengeh
# Processing Record 7 of Set 10 | sanbu
# Processing Record 8 of Set 10 | sarab
# Processing Record 9 of Set 10 | lukulu
# Processing Record 10 of Set 10 | labuan
# Processing Record 11 of Set 10 | georgiyevka
# Processing Record 12 of Set 10 | senneterre
# Processing Record 13 of Set 10 | richards bay
# Processing Record 14 of Set 10 | pacific grove
# Processing Record 15 of Set 10 | tornio
# Processing Record 16 of Set 10 | hopelchen
# Processing Record 17 of Set 10 | okha
# Processing Record 18 of Set 10 | miandrivazo
# Processing Record 19 of Set 10 | moratuwa
# Processing Record 20 of Set 10 | ambovombe
# Processing Record 21 of Set 10 | ugoofaaru
# Processing Record 22 of Set 10 | yaan
# Processing Record 23 of Set 10 | ulverstone
# Processing Record 24 of Set 10 | alanya
# Processing Record 25 of Set 10 | sucre
# Processing Record 26 of Set 10 | anadyr
# Processing Record 27 of Set 10 | senno
# Processing Record 28 of Set 10 | kemijarvi
# Processing Record 29 of Set 10 | chapleau
# Processing Record 30 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 31 of Set 10 | mae hong son
# Processing Record 32 of Set 10 | lola
# Processing Record 33 of Set 10 | braine-le-comte
# Processing Record 34 of Set 10 | vila do maio
# Processing Record 35 of Set 10 | poitiers
# Processing Record 36 of Set 10 | tay ninh
# Processing Record 37 of Set 10 | sinnamary
# Processing Record 38 of Set 10 | moose factory
# Processing Record 39 of Set 10 | thinadhoo
# Processing Record 40 of Set 10 | oranjemund
# Processing Record 41 of Set 10 | cafarnaum
# Processing Record 42 of Set 10 | touros
# Processing Record 43 of Set 10 | hokitika
# Processing Record 44 of Set 10 | beringovskiy
# Processing Record 45 of Set 10 | la ronge
# Processing Record 46 of Set 10 | mbuguni
# Processing Record 47 of Set 10 | mtambile
# Processing Record 48 of Set 10 | dingle
# Processing Record 49 of Set 10 | bagdarin
# Processing Record 50 of Set 10 | santa marta
# Processing Record 1 of Set 11 | dudinka
# Processing Record 2 of Set 11 | sayyan
# Processing Record 3 of Set 11 | kodinar
# Processing Record 4 of Set 11 | pokosnoye
# Processing Record 5 of Set 11 | muros
# Processing Record 6 of Set 11 | jinchengjiang
# City not found. Skipping...
# Processing Record 7 of Set 11 | brooks
# Processing Record 8 of Set 11 | gonbad-e qabus
# Processing Record 9 of Set 11 | ozernovskiy
# Processing Record 10 of Set 11 | santa catarina de tepehuanes
# Processing Record 11 of Set 11 | dunedin
# Processing Record 12 of Set 11 | malakal
# Processing Record 13 of Set 11 | tura
# Processing Record 14 of Set 11 | paamiut
# Processing Record 15 of Set 11 | sola
# Processing Record 16 of Set 11 | pozo colorado
# Processing Record 17 of Set 11 | rudnaya pristan
# Processing Record 18 of Set 11 | coquimbo
# Processing Record 19 of Set 11 | guiyang
# Processing Record 20 of Set 11 | fuxin
# Processing Record 21 of Set 11 | cidreira
# Processing Record 22 of Set 11 | outjo
# Processing Record 23 of Set 11 | erie
# Processing Record 24 of Set 11 | acarau
# Processing Record 25 of Set 11 | khasan
# Processing Record 26 of Set 11 | nizhnyaya tavda
# Processing Record 27 of Set 11 | tautira
# Processing Record 28 of Set 11 | nizwa
# Processing Record 29 of Set 11 | foix
# Processing Record 30 of Set 11 | hvolsvollur
# Processing Record 31 of Set 11 | moerai
# Processing Record 32 of Set 11 | monrovia
# Processing Record 33 of Set 11 | vestmannaeyjar
# Processing Record 34 of Set 11 | alvand
# Processing Record 35 of Set 11 | llangefni
# Processing Record 36 of Set 11 | waingapu
# Processing Record 37 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 38 of Set 11 | wufeng
# Processing Record 39 of Set 11 | hervey bay
# Processing Record 40 of Set 11 | micheweni
# Processing Record 41 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 42 of Set 11 | sivas
# Processing Record 43 of Set 11 | lompoc
# Processing Record 44 of Set 11 | samarai
# Processing Record 45 of Set 11 | arlit
# Processing Record 46 of Set 11 | pisco
# Processing Record 47 of Set 11 | nicoya
# Processing Record 48 of Set 11 | kosa
# Processing Record 49 of Set 11 | pitanga
# Processing Record 50 of Set 11 | marabba
# Processing Record 1 of Set 12 | tulun
# Processing Record 2 of Set 12 | ikungi
# Processing Record 3 of Set 12 | dhidhdhoo
# Processing Record 4 of Set 12 | byron bay
# Processing Record 5 of Set 12 | capitao poco
# Processing Record 6 of Set 12 | batemans bay
# Processing Record 7 of Set 12 | chimore
# Processing Record 8 of Set 12 | avera
# Processing Record 9 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 10 of Set 12 | olafsvik
# Processing Record 11 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 12 of Set 12 | pendleton
# Processing Record 13 of Set 12 | laguna
# Processing Record 14 of Set 12 | buctzotz
# Processing Record 15 of Set 12 | caravelas
# Processing Record 16 of Set 12 | upata
# Processing Record 17 of Set 12 | werda
# Processing Record 18 of Set 12 | gushikawa
# Processing Record 19 of Set 12 | sao borja
# Processing Record 20 of Set 12 | prainha
# Processing Record 21 of Set 12 | mauganj
# Processing Record 22 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 12 | zasheyek
# Processing Record 24 of Set 12 | el badari
# City not found. Skipping...
# Processing Record 25 of Set 12 | karratha
# Processing Record 26 of Set 12 | provost
# Processing Record 27 of Set 12 | yenagoa
# Processing Record 28 of Set 12 | iqaluit
# Processing Record 29 of Set 12 | hofn
# Processing Record 30 of Set 12 | alakurtti
# Processing Record 31 of Set 12 | beroroha
# Processing Record 32 of Set 12 | shubarshi
# Processing Record 33 of Set 12 | rundu
# Processing Record 34 of Set 12 | odesskoye
# Processing Record 35 of Set 12 | aripuana
# Processing Record 36 of Set 12 | labuhan
# Processing Record 37 of Set 12 | charyshskoye
# Processing Record 38 of Set 12 | pangai
# Processing Record 39 of Set 12 | stonewall
# Processing Record 40 of Set 12 | sao felix do xingu
# Processing Record 41 of Set 12 | compostela
# Processing Record 42 of Set 12 | hanna
# Processing Record 43 of Set 12 | nacala
# Processing Record 44 of Set 12 | kieta
# Processing Record 45 of Set 12 | los llanos de aridane
# Processing Record 46 of Set 12 | manjacaze
# Processing Record 47 of Set 12 | peachland
# Processing Record 48 of Set 12 | mnogovershinnyy
# Processing Record 49 of Set 12 | sri aman
# Processing Record 50 of Set 12 | camabatela
# Processing Record 1 of Set 13 | canton
# Processing Record 2 of Set 13 | bolshiye uki
# City not found. Skipping...
# Processing Record 3 of Set 13 | libreville
# Processing Record 4 of Set 13 | la rioja
# Processing Record 5 of Set 13 | kloulklubed
# Processing Record 6 of Set 13 | biltine
# Processing Record 7 of Set 13 | valkeakoski
# Processing Record 8 of Set 13 | glarus
# Processing Record 9 of Set 13 | agropoli
# Processing Record 10 of Set 13 | harwich
# Processing Record 11 of Set 13 | pueblo nuevo
# Processing Record 12 of Set 13 | tawnat
# City not found. Skipping...
# Processing Record 13 of Set 13 | campana
# Processing Record 14 of Set 13 | prudentopolis
# Processing Record 15 of Set 13 | maceio
# Processing Record 16 of Set 13 | villarrica
# Processing Record 17 of Set 13 | san buenaventura
# Processing Record 18 of Set 13 | muritiba
# Processing Record 19 of Set 13 | tabuk
# Processing Record 20 of Set 13 | kahului
# Processing Record 21 of Set 13 | vanimo
# Processing Record 22 of Set 13 | warri
# Processing Record 23 of Set 13 | pewaukee
# Processing Record 24 of Set 13 | jalu
# Processing Record 25 of Set 13 | bitkine
# Processing Record 26 of Set 13 | channel-port aux basques
# Processing Record 27 of Set 13 | santa vitoria
# Processing Record 28 of Set 13 | dubti
# Processing Record 29 of Set 13 | antoniny
# Processing Record 30 of Set 13 | canon city
# Processing Record 31 of Set 13 | havoysund
# Processing Record 32 of Set 13 | bozeman
# Processing Record 33 of Set 13 | harnosand
# Processing Record 34 of Set 13 | baruun-urt
# Processing Record 35 of Set 13 | kuytun
# Processing Record 36 of Set 13 | talesh
# City not found. Skipping...
# Processing Record 37 of Set 13 | rameswaram
# Processing Record 38 of Set 13 | abnub
# Processing Record 39 of Set 13 | rabo de peixe
# Processing Record 40 of Set 13 | tabulbah
# City not found. Skipping...
# Processing Record 41 of Set 13 | singaparna
# Processing Record 42 of Set 13 | isangel
# Processing Record 43 of Set 13 | am timan
# Processing Record 44 of Set 13 | kudahuvadhoo
# Processing Record 45 of Set 13 | komsomolskiy
# Processing Record 46 of Set 13 | jurmala
# Processing Record 47 of Set 13 | qaqortoq
# Processing Record 48 of Set 13 | lensk
# Processing Record 49 of Set 13 | hare bay
# Processing Record 50 of Set 13 | billings
# Processing Record 1 of Set 14 | safaga
# Processing Record 2 of Set 14 | vuktyl
# Processing Record 3 of Set 14 | santiago del estero
# Processing Record 4 of Set 14 | chone
# Processing Record 5 of Set 14 | khor
# Processing Record 6 of Set 14 | half moon bay
# Processing Record 7 of Set 14 | almaznyy
# Processing Record 8 of Set 14 | maragogi
# Processing Record 9 of Set 14 | kumluca
# Processing Record 10 of Set 14 | alpena
# Processing Record 11 of Set 14 | sesheke
# Processing Record 12 of Set 14 | dinsor
# City not found. Skipping...
# Processing Record 13 of Set 14 | grand-santi
# Processing Record 14 of Set 14 | santiago
# Processing Record 15 of Set 14 | papara
# Processing Record 16 of Set 14 | saint-francois
# Processing Record 17 of Set 14 | ukiah
# Processing Record 18 of Set 14 | vallenar
# Processing Record 19 of Set 14 | kadykchan
# City not found. Skipping...
# Processing Record 20 of Set 14 | kismayo
# Processing Record 21 of Set 14 | kuna
# Processing Record 22 of Set 14 | olinda
# Processing Record 23 of Set 14 | arivonimamo
# Processing Record 24 of Set 14 | ulvik
# Processing Record 25 of Set 14 | hanko
# Processing Record 26 of Set 14 | xining
# Processing Record 27 of Set 14 | lanivtsi
# Processing Record 28 of Set 14 | aguia branca
# Processing Record 29 of Set 14 | windhoek
# Processing Record 30 of Set 14 | moron
# Processing Record 31 of Set 14 | prachuap khiri khan
# Processing Record 32 of Set 14 | lucapa
# Processing Record 33 of Set 14 | kulykiv
# Processing Record 34 of Set 14 | san cristobal
# Processing Record 35 of Set 14 | manakara
# Processing Record 36 of Set 14 | soure
# Processing Record 37 of Set 14 | the valley
# Processing Record 38 of Set 14 | nsanje
# Processing Record 39 of Set 14 | wad rawah
# Processing Record 40 of Set 14 | ust-nera
# Processing Record 41 of Set 14 | ibra
# Processing Record 42 of Set 14 | tiznit
# Processing Record 43 of Set 14 | patamundai
# Processing Record 44 of Set 14 | filingue
# Processing Record 45 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 46 of Set 14 | anzio
# Processing Record 47 of Set 14 | carroll
# Processing Record 48 of Set 14 | mount isa
# Processing Record 49 of Set 14 | itaituba
# Processing Record 50 of Set 14 | luleburgaz
# Processing Record 1 of Set 15 | buala
# Processing Record 2 of Set 15 | grand gaube
# Processing Record 3 of Set 15 | victor harbor
# Processing Record 4 of Set 15 | tarko-sale
# Processing Record 5 of Set 15 | kasama
# Processing Record 6 of Set 15 | wanaka
# Processing Record 7 of Set 15 | gerash
# Processing Record 8 of Set 15 | annau
# Processing Record 9 of Set 15 | bonavista
# Processing Record 10 of Set 15 | jining
# Processing Record 11 of Set 15 | changji
# Processing Record 12 of Set 15 | algiers
# Processing Record 13 of Set 15 | blagoveshchensk
# Processing Record 14 of Set 15 | laje
# Processing Record 15 of Set 15 | gat
# Processing Record 16 of Set 15 | mbandaka
# Processing Record 17 of Set 15 | rotifunk
# Processing Record 18 of Set 15 | shelbyville
# Processing Record 19 of Set 15 | makakilo city
# Processing Record 20 of Set 15 | tadine
# Processing Record 21 of Set 15 | lat yao
# Processing Record 22 of Set 15 | wembley
# Processing Record 23 of Set 15 | bodo
# Processing Record 24 of Set 15 | aquiraz
# Processing Record 25 of Set 15 | newcastle
# Processing Record 26 of Set 15 | hinganghat
# Processing Record 27 of Set 15 | shiloh
# Processing Record 28 of Set 15 | zambezi
# Processing Record 29 of Set 15 | patti
# Processing Record 30 of Set 15 | vao
# Processing Record 31 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 32 of Set 15 | panguna
# Processing Record 33 of Set 15 | bintulu
# Processing Record 34 of Set 15 | bedele
# Processing Record 35 of Set 15 | vilyuysk
# Processing Record 36 of Set 15 | kawalu
# Processing Record 37 of Set 15 | monte cristi
# City not found. Skipping...
# Processing Record 38 of Set 15 | petatlan
# Processing Record 39 of Set 15 | muriti
# Processing Record 40 of Set 15 | alto araguaia
# Processing Record 41 of Set 15 | harper
# Processing Record 42 of Set 15 | sao joao da barra
# Processing Record 43 of Set 15 | linden
# Processing Record 44 of Set 15 | adrar
# Processing Record 45 of Set 15 | tromso
# Processing Record 46 of Set 15 | tabialan
# City not found. Skipping...
# Processing Record 47 of Set 15 | chimbote
# Processing Record 48 of Set 15 | vostok
# Processing Record 49 of Set 15 | mariental
# Processing Record 50 of Set 15 | la reforma
# Processing Record 1 of Set 16 | saraland
# Processing Record 2 of Set 16 | acajutla
# Processing Record 3 of Set 16 | bayonet point
# Processing Record 4 of Set 16 | sao jose da coroa grande
# Processing Record 5 of Set 16 | chesma
# Processing Record 6 of Set 16 | jiayuguan
# Processing Record 7 of Set 16 | trairi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(20)
# Out:
#                      City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Punta Arenas      CL -53.1500  -70.9167     50.00        71
# 1                   Kenai      US  60.5544 -151.2583     35.60        59
# 2              Butaritari      KI   3.0707  172.7902     81.46        78
# 3                   Amqui      CA  48.4638  -67.4313     42.80        81
# 4         Bambous Virieux      MU -20.3428   57.7575     80.01        88
# 5                  Atuona      PF  -9.8000 -139.0333     80.73        73
# 6                   Lagoa      PT  39.0500  -27.9833     59.22        92
# 7                 Batagay      RU  67.6333  134.6333      1.58        86
# 8           Mar Del Plata      AR -38.0023  -57.5575     71.60        83
# 9                 Rikitea      PF -23.1203 -134.9692     77.11        60
# 10               Buraydah      SA  26.3260   43.9750     71.60        23
# 11                Huarmey      PE -10.0681  -78.1522     70.50        86
# 12              Nantucket      US  41.2835  -70.0995     44.60        93
# 13               Hermanus      ZA -34.4187   19.2345     60.01        90
# 14              Busselton      AU -33.6500  115.3333     62.01        83
# 15               Smithers      CA  54.7804 -127.1743     39.20        52
# 16         Valvedditturai      LK   9.8167   80.1667     78.10        83
# 17                Ushuaia      AR -54.8000  -68.3000     46.40        87
# 18                Mataura      NZ -46.1927  168.8643     63.00        66
# 19  Conceicao Do Araguaia      BR  -8.2578  -49.2647     78.80        94
#
#     Cloudiness  Wind Speed Current Description
# 0            0       13.80           clear sky
# 1           90       10.36     overcast clouds
# 2          100       13.06          light rain
# 3           20        8.05          few clouds
# 4           75       12.66          light rain
# 5            5       15.26           clear sky
# 6           24       22.91          few clouds
# 7           61        1.21       broken clouds
# 8            1        9.22           clear sky
# 9            0        7.72           clear sky
# 10           0       10.36           clear sky
# 11          97        8.23     overcast clouds
# 12           1       12.66           clear sky
# 13         100        1.99     overcast clouds
# 14          33        1.99    scattered clouds
# 15          75        9.22       broken clouds
# 16          32        7.52    scattered clouds
# 17          40        3.71    scattered clouds
# 18          11        5.01          few clouds
# 19           0        3.44           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
