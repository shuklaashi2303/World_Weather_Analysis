# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_Vacation.csv")
vacation_df.head(10)
# Out:
#    City_ID         City Country  Max Temp Current Description      Lat  \
# 0       21     Zhigansk      RU     10.35     overcast clouds  66.7697
# 1       54   Kautokeino      NO     21.79     overcast clouds  69.0125
# 2       55    Maniitsoq      GL     28.08     overcast clouds  65.4167
# 3       75      College      US     18.00    scattered clouds  64.8569
# 4      105  Yellowknife      CA     19.40                snow  62.4560
# 5      130   Skelleftea      SE     28.40          few clouds  64.7507
# 6      132     Yar-Sale      RU     10.33     overcast clouds  66.8333
# 7      154         Asau      RO     28.40           clear sky  46.4333
# 8      164     Fagernes      NO     12.96       broken clouds  60.9858
# 9      174     Tasiilaq      GL     15.80           clear sky  65.6145
#
#         Lng                            Hotel Name
# 0  123.3711           Gostinichnyy Kompleks Aylgy
# 1   23.0412                 Thon Hotel Kautokeino
# 2  -52.9000                Hotel Heilmann Lyberth
# 3 -147.8028               Pike's Waterfront Lodge
# 4 -114.3525                    The Explorer Hotel
# 5   20.9528  Quality Hotel Skellefteå Stadshotell
# 6   70.8333                                Yalemd
# 7   26.4000                    Casa Mika Ciobanus
# 8    9.2324                       Scandic Valdres
# 9  -37.6368                         The Red House

# %%
vacation_df.reset_index(drop=True,inplace=True)
vacation_df
# Out:
#     City_ID             City Country  Max Temp Current Description      Lat  \
# 0        21         Zhigansk      RU     10.35     overcast clouds  66.7697
# 1        54       Kautokeino      NO     21.79     overcast clouds  69.0125
# 2        55        Maniitsoq      GL     28.08     overcast clouds  65.4167
# 3        75          College      US     18.00    scattered clouds  64.8569
# 4       105      Yellowknife      CA     19.40                snow  62.4560
# 5       130       Skelleftea      SE     28.40          few clouds  64.7507
# 6       132         Yar-Sale      RU     10.33     overcast clouds  66.8333
# 7       154             Asau      RO     28.40           clear sky  46.4333
# 8       164         Fagernes      NO     12.96       broken clouds  60.9858
# 9       174         Tasiilaq      GL     15.80           clear sky  65.6145
# 10      177            Vardo      NO     21.20           clear sky  70.3705
# 11      184             Lasa      IT     27.00    scattered clouds  46.6166
# 12      199     Longyearbyen      SJ     23.00          light snow  78.2186
# 13      207        Fairbanks      US     19.00           clear sky  64.8378
# 14      208        Ostersund      SE     24.80          few clouds  63.1792
# 15      266             Ayan      RU     24.53          light snow  56.4500
# 16      271        Ilulissat      GL     12.20       broken clouds  69.2167
# 17      316           Mehamn      NO     25.66    scattered clouds  71.0357
# 18      322     Norman Wells      CA     10.40          few clouds  65.2820
# 19      328         Ilmajoki      FI     25.00           clear sky  62.7333
# 20      333          Husavik      IS     23.00          light snow  66.0449
# 21      341           Tommot      RU     18.55     overcast clouds  58.9564
# 22      367          Magadan      RU     20.01          few clouds  59.5667
# 23      379             Tahe      CN     28.92    scattered clouds  52.3333
# 24      421           Tornio      FI     21.20           clear sky  65.8481
# 25      434        Kemijarvi      FI     20.50    scattered clouds  66.7131
# 26      468          Paamiut      GL     29.35     overcast clouds  61.9940
# 27      484      Hvolsvollur      IS     25.00                snow  63.7533
# 28      511         Olafsvik      IS     27.64     overcast clouds  64.8945
# 29      522         Zasheyek      RU     28.99       broken clouds  67.4066
# 30      527             Hofn      IS     27.10          light snow  64.2539
# 31      528        Alakurtti      RU     30.00          light snow  66.9672
# 32      546  Mnogovershinnyy      RU     25.79     overcast clouds  53.9353
# 33      554      Valkeakoski      FI     30.00           clear sky  61.2642
# 34      579        Harnosand      SE     28.40           clear sky  62.6323
# 35      596           Vuktyl      RU     28.40     overcast clouds  63.8567
# 36      609   Saint-Francois      FR     27.00           clear sky  46.4154
# 37      616            Ulvik      NO     23.83     overcast clouds  60.5672
# 38      632         Ust-Nera      RU     10.56     overcast clouds  64.5667
# 39      645       Tarko-Sale      RU     23.86     overcast clouds  64.9225
# 40      654  Blagoveshchensk      RU     28.40           clear sky  50.2667
# 41      675         Vilyuysk      RU     17.44          light snow  63.7553
#
#          Lng                                    Hotel Name
# 0   123.3711                   Gostinichnyy Kompleks Aylgy
# 1    23.0412                         Thon Hotel Kautokeino
# 2   -52.9000                        Hotel Heilmann Lyberth
# 3  -147.8028                       Pike's Waterfront Lodge
# 4  -114.3525                            The Explorer Hotel
# 5    20.9528          Quality Hotel Skellefteå Stadshotell
# 6    70.8333                                        Yalemd
# 7    26.4000                            Casa Mika Ciobanus
# 8     9.2324                               Scandic Valdres
# 9   -37.6368                                 The Red House
# 10   31.1107                                Vardø Hotel AS
# 11   10.7002                         Pension Feldgärtenhof
# 12   15.6401         Radisson Blu Polar Hotel, Spitsbergen
# 13 -147.7164  Westmark Fairbanks Hotel & Conference Center
# 14   14.6357              Best Western Hotel Gamla Teatern
# 15  138.1667                                    Gostinitsa
# 16  -51.1000                                  Hotel Arctic
# 17   27.8492                        Mehamn Arctic Hotel AS
# 18 -126.8329                                Heritage Hotel
# 19   22.5667                         KesäHostelli Ilmajoki
# 20  -17.3389                                     Bjarnabúð
# 21  126.2925                             Gostinitsa Tommot
# 22  150.8000                                 Magadan hotel
# 23  124.7333                                          塔河宾馆
# 24   24.1466                             Park Hotel Tornio
# 25   27.4306                             Hotelli Kemijärvi
# 26  -49.6678                                    Yeet Hotel
# 27  -20.2243                                   Hotel Rangá
# 28  -23.7142                                Hotel Olafsvik
# 29   32.5499                                      Khostiel
# 30  -15.2082                                    Hótel Höfn
# 31   30.3491                      Agroturystyka Gientosław
# 32  139.9242                             Kvartsevaya Sopka
# 33   24.0312                                Hotel Waltikka
# 34   17.9379                             First Hotel Stadt
# 35   57.3094                          Mini-Hotel Lokomotiv
# 36    3.9054                             Manoir Du Bonheur
# 37    6.9187                                   Ulvik Hotel
# 38  143.2000                                Hotel Ust-Nera
# 39   77.7850                                   Yubileynaya
# 40  127.5333                                 Green Hostels
# 41  121.6247                           Gostinitsa Viliuisk

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)

# %%
# 4a. Add a marker layer for each city to the map.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
markers = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(markers)

# 4b. Display the figure

fig.add_layer(gmaps.heatmap_layer(locations, weights=max_temp, max_intensity=300, dissipating=False, point_radius=4, opacity=0.7, gradient=None))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.
start = "Ust-Nera"
end = "Ust-Nera"
stop1 = "Tarko-Sale"
stop2 = "Blagoveshchensk"
stop3 = "Vilyuysk"

vacation_start = vacation_df.loc[vacation_df["City"] == start]
vacation_end = vacation_df.loc[vacation_df["City"] == end]
vacation_stop1 = vacation_df.loc[vacation_df["City"] == stop1]
vacation_stop2 = vacation_df.loc[vacation_df["City"] == stop2] 
vacation_stop3 = vacation_df.loc[vacation_df["City"] == stop3]

vacation_start
vacation_end
vacation_stop1
vacation_stop2
vacation_stop3
# Out:
#     City_ID      City Country  Max Temp Current Description      Lat  \
# 41      675  Vilyuysk      RU     17.44          light snow  63.7553
#
#          Lng           Hotel Name
# 41  121.6247  Gostinitsa Viliuisk

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start[["Lat", "Lng"]].to_numpy()[0]
end = vacation_end[["Lat", "Lng"]].to_numpy()[0]
stop1 = vacation_stop1[["Lat", "Lng"]].to_numpy()[0]
stop2 = vacation_stop2[["Lat", "Lng"]].to_numpy()[0]
stop3 = vacation_stop3[["Lat", "Lng"]].to_numpy()[0]
start
# Out:
# array([ 64.5667, 143.2   ])

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
fig = gmaps.figure()
travel_route = gmaps.directions_layer(start, end, waypoints=[stop1,stop2,stop3], travel_mode="DRIVING" or "BICYCLING" or "WALKING")
fig.add_layer(travel_route)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop1, vacation_stop2, vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID             City Country  Max Temp Current Description      Lat  \
# 0      632         Ust-Nera      RU     10.56     overcast clouds  64.5667
# 1      645       Tarko-Sale      RU     23.86     overcast clouds  64.9225
# 2      654  Blagoveshchensk      RU     28.40           clear sky  50.2667
# 3      675         Vilyuysk      RU     17.44          light snow  63.7553
#
#         Lng           Hotel Name
# 0  143.2000       Hotel Ust-Nera
# 1   77.7850          Yubileynaya
# 2  127.5333        Green Hostels
# 3  121.6247  Gostinitsa Viliuisk

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]
max_temp = itinerary_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)

# %%
# 11a. Add a marker layer for each city to the map.
fig = gmaps.figure()
markers = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(markers)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
